# %%
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt
import numpy as np

# %%
img_height, img_width = (224, 224)
batch_size = 32
IMAGE_SIZE = [224, 224]
train_data_dir = r"ClickMe\Processed_Data\train"
valid_data_dir = r"ClickMe\Processed_Data\val"
test_data_dir = r"ClickMe\Processed_Data\test"

# %%
train_datagen = ImageDataGenerator(preprocessing_function = preprocess_input)
                                  
train_gen = train_datagen.flow_from_directory(
    train_data_dir,
    target_size = (img_height, img_width),
    batch_size = batch_size,
    class_mode = 'categorical')

valid_gen = train_datagen.flow_from_directory(
    valid_data_dir,
    target_size = (img_height, img_width),
    batch_size = batch_size,
    class_mode = 'categorical')
# Out:
# Found 6666 images belonging to 32 classes.
# Found 351 images belonging to 32 classes.

# %%
test_gen = train_datagen.flow_from_directory(
    test_data_dir,
    target_size = (img_height, img_width),
    batch_size = 1,
    class_mode = 'categorical')
# Out:
# Found 378 images belonging to 32 classes.

# %%
base_model = ResNet50(input_shape=IMAGE_SIZE + [3], include_top = False, weights = 'imagenet')

for layer in base_model.layers:
    layer.trainable = False
    
x = Flatten()(base_model.output)
predictions = Dense(train_gen.num_classes, activation='softmax')(x)
model = Model(inputs = base_model.input, outputs = predictions)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# ...

# %%
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
result = model.fit(
  train_gen,
  validation_data=valid_gen,
  epochs=20,
  steps_per_epoch=len(train_gen),
  validation_steps=len(valid_gen)
)
# Out:
# Epoch 1/20
# 209/209 [==============================] - 669s 3s/step - loss: 7.5006 - accuracy: 0.7264 - val_loss: 2.4967 - val_accuracy: 0.9288
# Epoch 2/20
# 209/209 [==============================] - 680s 3s/step - loss: 0.5623 - accuracy: 0.9673 - val_loss: 2.6625 - val_accuracy: 0.9316
# Epoch 3/20
# 209/209 [==============================] - 693s 3s/step - loss: 0.3689 - accuracy: 0.9824 - val_loss: 3.1074 - val_accuracy: 0.9459
# Epoch 4/20
# 209/209 [==============================] - 695s 3s/step - loss: 0.2940 - accuracy: 0.9862 - val_loss: 2.5719 - val_accuracy: 0.9573
# Epoch 5/20
# 209/209 [==============================] - 719s 3s/step - loss: 0.1553 - accuracy: 0.9928 - val_loss: 3.7069 - val_accuracy: 0.9345
# Epoch 6/20
# 209/209 [==============================] - 714s 3s/step - loss: 0.2358 - accuracy: 0.9892 - val_loss: 4.5198 - val_accuracy: 0.9202
# Epoch 7/20
# ...

# %%
model.save('ClickMe\Saved_Model\ThesisTranfer1.h5')

# %%
test_loss, test_acc = model.evaluate(test_gen, verbose = 2)
print ('\nTest Accuracy:', test_acc)
# Out:
# 378/378 - 44s - loss: 6.6688 - accuracy: 0.9392
#
# Test Accuracy: 0.9391534328460693

# %%
val_loss, val_acc = model.evaluate(valid_gen, verbose = 2)
print ('\nValidation Accuracy:', val_acc)
# Out:
# 11/11 - 34s - loss: 7.5738 - accuracy: 0.9259
#
# Validation Accuracy: 0.9259259104728699

# %%
train_gen.class_indices.keys()
# Out:
# dict_keys(['Beef Meat', 'Bellpepper', 'Burger Bun', 'Burger Patty', 'Checkpea', 'Cheese', 'Chicken', 'Chocolate', 'Chocolate Syrup', 'Donut Bun', 'Egg', 'Ground Beef', 'Hotdog Bun', 'Ice Cream', 'Lasagna Noodles', 'Letus', 'Mayonnaise', 'Milk', 'Mushrooms', 'Nachos Chips', 'Noodles', 'Onion', 'Pasta', 'Pizza Dough', 'Potato', 'Rice', 'Roll Bread', 'Sandwich Bread', 'Sausage', 'Shawarma Bread', 'Subway Bun', 'Tomato'])

# %%
import pandas as pd
import seaborn as sn
import tensorflow as tf

model = tf.keras.models.load_model("ClickMe\Saved_Model\ThesisTranfer1.h5")
filenames = test_gen.filenames
nb_samples = len(test_gen)
y_prob = []
y_act = []
test_gen.reset()
for _ in range(nb_samples):
    X_test, Y_test = test_gen.next()
    y_prob.append(model.predict(X_test))
    y_act.append(Y_test)
    
predicted_class = [list(train_gen.class_indices.keys())[i.argmax()] for i in y_prob]
actual_class = [list(train_gen.class_indices.keys())[i.argmax()] for i in y_act]
out_df = pd.DataFrame(np.vstack([predicted_class, actual_class]).T , columns = ['predicted_class', 'actual_class'])
confusion_matrix = pd.crosstab(out_df['actual_class'], out_df['predicted_class'], rownames = ['Actual'], colnames = ['Predicted'])

sn.heatmap(confusion_matrix, cmap = 'Blues', linewidth = 0.5, annot = True, fmt = 'd')
plt.show()
print('test accuracy: {}'.format((np.diagonal(confusion_matrix).sum()/confusion_matrix.sum().sum()*100)))
# Out:
# test accuracy: 11.904761904761903

# %%
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import cv2
import os

# %%
dir_path = 'Test'
for i in os.listdir(dir_path):
    img = image.load_img(dir_path+'//'+i, target_size=(224, 224))
    plt.imshow(img)
    plt.show()
    model = tf.keras.models.load_model("ClickMe\Saved_Model\ThesisTranfer1.h5")
    R = image.img_to_array(img)
    R = np.expand_dims(R, axis = 0)
    images = np.vstack([R])
    Predictions = model.predict(images)
    Food = np.argmax(Predictions)
    print(Food)
    
    if Food == 0:
        print("Beef Meat")
    elif Food == 1:
        print("Bellpepper")
    elif Food == 2:
        print("Burger Bun")
    elif Food == 3:
        print("Burger Patty")
    elif Food == 4:
        print("Cheakpea")
    elif Food == 5:
        print("Cheese")
    elif Food == 6:
        print("Chicken")
    elif Food == 7:
        print("Chocolate")
    elif Food == 8:
        print("Chocolate Syrup")
    elif Food == 9:
        print("Donut Bun")
    elif Food == 10:
         print("Egg")
    elif Food == 11:
        print("Ground Beef")  
    elif Food == 12:
        print("Hotdog Bun")
    elif Food == 13:
        print("Ice Cream")
    elif Food == 14:
        print("Lasagna Noodles")
    elif Food == 15:
         print("Letus")
    elif Food == 16:
        print("Mayonnaise")  
    elif Food == 17:
        print("Milk")
    elif Food == 18:
        print("Mushrooms")
    elif Food == 19:
        print("Nachos Chips")
    elif Food == 20:
         print("Noodles")
    elif Food == 21:
        print("Onion") 
    elif Food == 22:
        print("Pasta")
    elif Food == 23:
        print("Pizza Dough") 
    elif Food == 24:
        print("Potato")
    elif Food == 25:
        print("Rice")
    elif Food == 26:
        print("Roll Bread")
    elif Food == 27:
        print("SandWich Bread")
    elif Food == 28:
        print("Sausage") 
    elif Food == 29:
        print("Shawarma Bread")
    elif Food == 30:
        print("Subway Bun")
    elif Food == 31:
        print("Tomato")
# Out:
# 25
# Rice
# 13
# Ice Cream
# 25
# Rice
# 25
# Rice
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002366A01CB80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 25
# Rice
# ...

# %%
plt.plot(result.history['loss'], label='train loss')
plt.plot(result.history['val_loss'], label='val loss')
plt.legend()
plt.show()
plt.savefig('Val_loss')

# %%
# accuracies
plt.plot(result.history['accuracy'], label='train acc')
plt.plot(result.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()
plt.savefig('AccVal_acc')

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sn
import tensorflow as tf

#anomodel = tf.keras.models.load_model("ClickMe\Saved_Model\ThesisModelTest1.h5")
#filenames = test_gen.filenames
nb_samples = len(test_gen)
y_prob = []
y_act = []
test_gen.reset()
for _ in range(nb_samples):
    X_test, Y_test = test_gen.next()
    y_prob.append(model.predict(X_test))
    y_act.append(Y_test)
#cm = confusion_matrix([list(train_gen.class_indices.keys())[i.argmax()] for i in y_act], [list(train_gen.class_indices.keys())[i.argmax()] for i in y_prob]) 
cm = confusion_matrix([[i.argmax()] for i in y_act], [[i.argmax()] for i in y_prob]) 
sn.heatmap(cm, cmap = 'Blues', linewidth = 0.5, annot = True, fmt = 'd')
plt.show()
print('test accuracy: {}'.format((np.diagonal(cm).sum()/cm.sum().sum()*100)))
# Out:
# test accuracy: 93.91534391534393
